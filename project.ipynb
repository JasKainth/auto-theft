# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

df = pd.read_csv('/Users/chandnimelwani/Documents/Data_Science_UFT/ML/Project/Data/Auto_Theft_Open_Data.csv')

# %%
df.head()
# Out:
#            X          Y  OBJECTID EVENT_UNIQUE_ID             REPORT_DATE  \
# 0 -79.306757  43.734652         1  GO-20141263217  2014/01/01 05:00:00+00
# 1 -79.236189  43.721847         2  GO-20141262914  2014/01/01 05:00:00+00
# 2 -79.529478  43.618472         3  GO-20141262837  2014/01/01 05:00:00+00
# 3 -79.516814  43.683438         4  GO-20141265795  2014/01/02 05:00:00+00
# 4 -79.595364  43.744281         5  GO-20141265947  2014/01/02 05:00:00+00
#
#                  OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  \
# 0  2013/12/31 05:00:00+00         2014      January           1           1
# 1  2014/01/01 05:00:00+00         2014      January           1           1
# 2  2013/12/25 05:00:00+00         2014      January           1           1
# 3  2014/01/01 05:00:00+00         2014      January           2           2
# 4  2014/01/01 05:00:00+00         2014      January           2           2
#
# ...

# %%
df.tail()
# Out:
#                X          Y  OBJECTID EVENT_UNIQUE_ID             REPORT_DATE  \
# 46043 -79.448803  43.743792     46044  GO-20222559870  2022/12/31 05:00:00+00
# 46044 -79.451561  43.746985     46045  GO-20222560433  2022/12/31 05:00:00+00
# 46045 -79.485320  43.778947     46046  GO-20222561916  2022/12/31 05:00:00+00
# 46046 -79.556765  43.765449     46047  GO-20222558651  2022/12/31 05:00:00+00
# 46047 -79.556765  43.765449     46048  GO-20222558651  2022/12/31 05:00:00+00
#
#                      OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  \
# 46043  2022/12/31 05:00:00+00         2022     December          31
# 46044  2022/12/30 05:00:00+00         2022     December          31
# 46045  2022/12/29 05:00:00+00         2022     December          31
# 46046  2022/12/31 05:00:00+00         2022     December          31
# 46047  2022/12/31 05:00:00+00         2022     December          31
#
#        REPORT_DOY  REPORT_DOW  REPORT_HOUR  OCC_YEAR OCC_MONTH  OCC_DAY  \
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'EVENT_UNIQUE_ID', 'REPORT_DATE', 'OCC_DATE',
#        'REPORT_YEAR', 'REPORT_MONTH', 'REPORT_DAY', 'REPORT_DOY', 'REPORT_DOW',
#        'REPORT_HOUR', 'OCC_YEAR', 'OCC_MONTH', 'OCC_DAY', 'OCC_DOY', 'OCC_DOW',
#        'OCC_HOUR', 'DIVISION', 'LOCATION_TYPE', 'PREMISES_TYPE', 'UCR_CODE',
#        'UCR_EXT', 'OFFENCE', 'MCI_CATEGORY', 'HOOD_158', 'NEIGHBOURHOOD_158',
#        'HOOD_140', 'NEIGHBOURHOOD_140', 'LONG_WGS84', 'LAT_WGS84'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   X             Y      OBJECTID   REPORT_YEAR    REPORT_DAY  \
# count  46048.000000  46048.000000  46048.000000  46048.000000  46048.000000
# mean     -79.490105     43.287412  23024.500000   2018.877867     15.681246
# std        0.609484      4.319873  13293.056935      2.597967      8.701205
# min      -85.488744      0.000000      1.000000   2014.000000      1.000000
# 25%      -79.526515     43.678596  11512.750000   2017.000000      8.000000
# 50%      -79.441336     43.719408  23024.500000   2019.000000     16.000000
# 75%      -79.346656     43.757442  34536.250000   2021.000000     23.000000
# max      -78.694889     44.096282  46048.000000   2022.000000     31.000000
#
#          REPORT_DOY   REPORT_HOUR      OCC_YEAR       OCC_DAY       OCC_DOY  \
# count  46048.000000  46048.000000  46044.000000  46044.000000  46044.000000
# mean     192.608517     11.513442   2018.863435     15.584506    192.187994
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46048 entries, 0 to 46047
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  46048 non-null  float64
#  1   Y                  46048 non-null  float64
#  2   OBJECTID           46048 non-null  int64
#  3   EVENT_UNIQUE_ID    46048 non-null  object
#  4   REPORT_DATE        46048 non-null  object
#  5   OCC_DATE           46048 non-null  object
#  6   REPORT_YEAR        46048 non-null  int64
#  7   REPORT_MONTH       46048 non-null  object
#  8   REPORT_DAY         46048 non-null  int64
#  9   REPORT_DOY         46048 non-null  int64
#  10  REPORT_DOW         46048 non-null  object
#  11  REPORT_HOUR        46048 non-null  int64
#  12  OCC_YEAR           46044 non-null  float64
#  13  OCC_MONTH          46044 non-null  object
#  14  OCC_DAY            46044 non-null  float64
#  15  OCC_DOY            46044 non-null  float64
# ...

# %%
print(df.isnull().sum())
# Out:
# X                    0
# Y                    0
# OBJECTID             0
# EVENT_UNIQUE_ID      0
# REPORT_DATE          0
# OCC_DATE             0
# REPORT_YEAR          0
# REPORT_MONTH         0
# REPORT_DAY           0
# REPORT_DOY           0
# REPORT_DOW           0
# REPORT_HOUR          0
# OCC_YEAR             4
# OCC_MONTH            4
# OCC_DAY              4
# OCC_DOY              4
# OCC_DOW              4
# OCC_HOUR             0
# DIVISION             0
# LOCATION_TYPE        0
# PREMISES_TYPE        0
# UCR_CODE             0
# UCR_EXT              0
# OFFENCE              0
# MCI_CATEGORY         0
# HOOD_158             0
# NEIGHBOURHOOD_158    0
# HOOD_140             0
# NEIGHBOURHOOD_140    0
# LONG_WGS84           0
# LAT_WGS84            0
# dtype: int64

# %%
counts_neighbourhood = df[['NEIGHBOURHOOD_140']].value_counts()
print(counts_neighbourhood)
# Out:
# NEIGHBOURHOOD_140
# West Humber-Clairville (1)                  3869
# Islington-City Centre West (14)             1360
# York University Heights (27)                1234
# Downsview-Roding-CFB (26)                   1205
# Humber Summit (21)                           923
# Glenfield-Jane Heights (25)                  736
# Wexford/Maryvale (119)                       722
# Yorkdale-Glen Park (31)                      709
# Rouge (131)                                  679
# Woburn (137)                                 672
# Mount Olive-Silverstone-Jamestown (2)        658
# Waterfront Communities-The Island (77)       633
# Bedford Park-Nortown (39)                    618
# Milliken (130)                               601
# Newtonbrook West (36)                        578
# Clanton Park (33)                            549
# Kingsview Village-The Westway (6)            542
# NSA                                          537
# Bendale (127)                                536
# ...

# %%
counts = df[['OCC_YEAR', 'OCC_MONTH', 'OCC_DOW', \
                     'OCC_HOUR', 'DIVISION', 'LOCATION_TYPE', 
                    'PREMISES_TYPE','NEIGHBOURHOOD_140']].value_counts()
print(counts)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
counts1 = df.groupby(['OCC_YEAR', 'OCC_MONTH', 'OCC_MONTH', 'OCC_DOW', \
                     'OCC_HOUR']).size()
print(counts)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
'DIVISION', 'LOCATION_TYPE', 'PREMISES_TYPE', \
                     'NEIGHBOURHOOD_140'])

# %%
num_duplicates = df.duplicated(subset=['OCC_YEAR', 'OCC_MONTH', 'OCC_MONTH', 'OCC_DOW', \
                     'OCC_HOUR', 'DIVISION', 'LOCATION_TYPE', 
                    'PREMISES_TYPE','NEIGHBOURHOOD_140']).sum()
print("Value counts:", num_duplicates)
# Out:
# Value counts: 4707

# %%
df['Combined'] = df.astype(str).apply(lambda x: ''.join(x), axis=1)
frequency = df['Combined'].value_counts()
print(frequency)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
auto_theft_data = [['NEIGHBOURHOOD_140', 'OFFENCE']]

# %%
auto_theft_count = auto_theft_data[auto_theft_data['OFFENCE'] == 'Auto Theft']['NEIGHBOURHOOD_158'].value_counts()
print(auto_theft_count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 auto_theft_count = auto_theft_data[auto_theft_data['OFFENCE'] == 'Auto Theft']['NEIGHBOURHOOD_158'].value_counts()
#       2 print(auto_theft_count)
#
# TypeError: list indices must be integers or slices, not str
